# %%
from  sympy import *

# %%
x = Symbol("x")

# %%
f, g = Symbol('f(x)'), Symbol('g(x)')

# %%
funcF = x**3 - 50 * x

# %%
funcG = -x**4 + 88 * x**2 - 241

# %%
funcE = funcF -funcG

# %%
plot(funcF, funcG)

# %%
plot(funcE)

# %%
a = solve(funcE)

# %%
a = [a[i].evalf(5, chop = True) for i in range(4)]

# %%
a[0]
# Out:
# -9.4594

# %%
a[1]
# Out:
# 1.4182

# %%
a[2]
# Out:
# -1.9893

# %%
a[3]
# Out:
# 9.0306
